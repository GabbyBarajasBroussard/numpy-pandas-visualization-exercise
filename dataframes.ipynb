# %% [markdown]
# Your work for this exercise in a python script or a jupyter notebook with the name dataframes.py or dataframes.ipynb.
#
# For several of the following exercises, you'll need to load several datasets using the pydataset library. (If you get an error when trying to run the import below, use pip to install the pydataset package.)

# %% [markdown]
# from pydataset import data
# When the instructions say to load a dataset, you can pass the name of the dataset as a string to the data function to load the dataset. You can also view the documentation for the data set by passing the show_doc keyword argument.

# %%
import numpy as np
import math
import pandas as pd
from pydataset import data

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# All the datasets loaded from the pydataset library will be pandas dataframes.<br><br><br>
#
# ## Copy the code from the lesson to create a dataframe full of student grades.

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english > 70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(by='passing_english') 
#The automatic sorting style has the nonpassing students at the top and the order is by key (the number they are assigned (6,7,8 etc))
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically.

# %% [markdown]
# The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by=['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall_grade'] =(df.math+df.english+df.reading)/3
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# ## Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg')

# %% [markdown]
# How many rows and columns are there?

# %%
mpg.info()
#There are 234 rows and 11 columns in the MPG dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# What are the data types of each column?

# %% [markdown]
# #### The data types of each column are  object, float64, and int64.

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Rename the cty column to city.

# %%
mpg.rename(columns={'cty': 'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# Rename the hwy column to highway.
# .inplace = True holds the rename

# %%
mpg.rename(columns={'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.cty > mpg.hwy].sort_values(by='cty')
mpg
#No, all the cares have better highway mileage than city mileage
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference']= (mpg.hwy-mpg.cty)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by='mileage_difference', ascending=False)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f   24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f   29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f   18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f   18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f   18
# ..           ...                ...    ...   ...  ...         ...  ..  ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4   14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4   14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4   15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4   15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
#
#      hwy fl       class  mileage_difference
# ...

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
mpg.loc[mpg['class'] == 'compact'].sort_values(by=['hwy'])
# the worst highway mileage: 220	volkswagen	jetta	2.8	1999	6	auto(l4)	f	16	23	r	compact	7
# best hwy mileage: 213	volkswagen	jetta	1.9	1999	4	manual(m5)	f	33	44	d	compact	11
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 220   volkswagen         jetta    2.8  1999    6    auto(l4)   f   16   23  r
# 221   volkswagen         jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 212   volkswagen           gti    2.8  1999    6  manual(m5)   f   17   24  r
# 172       subaru   impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 170       subaru   impreza awd    2.5  2008    4    auto(s4)   4   20   25  p
# 15          audi    a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
# 14          audi    a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 13          audi    a4 quattro    2.8  1999    6  manual(m5)   4   17   25  p
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 12          audi    a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 209   volkswagen           gti    2.0  1999    4    auto(l4)   f   19   26  r
# ...

# %%
mpg.loc[mpg['class'] == 'compact'].sort_values(by=['hwy']).head(5)
#the s
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 220   volkswagen        jetta    2.8  1999    6    auto(l4)   f   16   23  r
# 221   volkswagen        jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 212   volkswagen          gti    2.8  1999    6  manual(m5)   f   17   24  r
# 172       subaru  impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 170       subaru  impreza awd    2.5  2008    4    auto(s4)   4   20   25  p
#
#        class  mileage_difference
# 220  compact                   7
# 221  compact                   7
# 212  compact                   7
# 172  compact                   6
# 170  compact                   5

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage']= (mpg.hwy+mpg.cty)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %% [markdown]
# Which dodge car has the best average mileage? The worst?

# %%
mpg.loc[mpg['manufacturer'] == 'dodge'].sort_values(by=['average_mileage'], ascending = False).tail()
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4   11
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  mileage_difference  average_mileage
# 74   15  r  pickup                   4             13.0
# 66   12  e  pickup                   3             10.5
# 60   12  e     suv                   3             10.5
# 55   12  e  pickup                   3             10.5
# 70   12  e  pickup                   3             10.5

# %%
mpg.loc[mpg['manufacturer'] == 'dodge'].sort_values(by=['average_mileage'], ascending = False).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  mileage_difference  average_mileage
# 38  minivan                   6             21.0

# %% [markdown]
# ## Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals=data('Mammals')
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %% [markdown]
# How many rows and columns are there?

# %%
mammals.info()
#there are 4 columns 
# there are 107 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %% [markdown]
# What are the data types?

# %% [markdown]
# #### The data types are float64 and bool.

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
mammals.sort_values('speed', ascending=False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# What is the overall percentage of specials?

# %%
mammals['specials'].value_counts()
percent= (10/97)
percent= percent * 100
percent= percent
print(round(percent, 2),"% are specials")
# Out:
# 10.31 % are specials

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
median_speed= mammals[('speed')].median()
mammals['median_speed']= median_speed

# %%
hopper_mammals =mammals.loc[mammals['hoppers'] == True]

# %%
hopper_mammals.loc[mammals['speed'] > median_speed]
#There are 4 animals slower than the median speed and there are 7 faster than the median speed
# Out:
#      weight  speed  hoppers  specials  median_speed
# 96      4.6   64.0     True     False          48.0
# 97      4.4   72.0     True     False          48.0
# 98      4.0   72.0     True     False          48.0
# 99      3.5   56.0     True     False          48.0
# 100     2.0   64.0     True     False          48.0
# 101     1.9   56.0     True     False          48.0
# 102     1.5   50.0     True     False          48.0

# %%
# Out:
# To github.com:GabbyBarajasBroussard/numpy-pandas-visualization-exercise
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'git@github.com:GabbyBarajasBroussard/numpy-pandas-visualization-exercise'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
